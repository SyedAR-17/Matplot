# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedAR-17/Matplot/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Matplotlib documentation: https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Title, labels and Plot
plt.title("PLOT", fontdict = {'color': 'red', 'fontweight': 'bold'})
plt.xlabel("x")
plt.ylabel("y")

# Ticks
# plt.xticks([1,2,3])
# plt.yticks([2,4,6])

# Figure Size
plt.plot(figsize=(10,5))

# Second Line
x2 = np.arange(0,3.5,0.5)
plt.plot(x2[:5], x2[:5]**2, label="X-Squared", color='blue', linewidth = '2', linestyle = '-', marker = '.', markersize = '20', markeredgecolor = 'yellow')
plt.plot(x2[4:], x2[4:]**2, color='blue', linewidth = '2', linestyle = '--', marker = '.', markersize = '20', markeredgecolor = 'yellow')

plt.plot(x,y, label="2x", color='red', linewidth = '2', linestyle = '--', marker = '.', markersize = '10', markeredgecolor = 'black')
plt.legend()
plt.show()
